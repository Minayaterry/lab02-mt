# %% [markdown]
# <a href="https://colab.research.google.com/github/Minayaterry/lab02-mt/blob/main/LABORATORIO3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SEMANA 3: ARQUITECTURA DE UN DATA WAREHOUSE. CARGA Y MANTENIMIENTO. CUBOS DE DATOS**

# %% [markdown]
# **Nombre: MINAYA TORRES, TERRY**

# %%
# importando las librerias
import pandas as pd
import numpy as np
import timeit

# %%
# 1. Cargando los datos desde el repositorio UCI
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data"
column_names = ["buying", "maint", "doors", "persons", "lug_boot", "safety", "class"]
data = pd.read_csv(url, names=column_names)

# %%
# 2. Exploración de datos
print("Forma del dataset:", data.shape)
print("Primeras filas:")
print(data.head())
print("Últimos registros:")
print(data.tail())
print("Tipos de datos:")
print(data.dtypes)
# Out:
# Forma del dataset: (1728, 7)
# Primeras filas:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc
# Últimos registros:
#      buying maint  doors persons lug_boot safety  class
# 1723    low   low  5more    more      med    med   good
# 1724    low   low  5more    more      med   high  vgood
# 1725    low   low  5more    more      big    low  unacc
# 1726    low   low  5more    more      big    med   good
# 1727    low   low  5more    more      big   high  vgood
# Tipos de datos:
# buying      object
# maint       object
# doors       object
# persons     object
# lug_boot    object
# safety      object
# class       object
# dtype: object

# %%
#extrayendo los nombres de los atributos de la base de datos original
list(data)
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
#extrayendo los nombres de los atributos de la base de datos original
list(data.columns)
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
#extrayendo los nombres de los atributos de la base de datos original
data.columns.tolist()
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
#extrayendo los nombres de los atributos de la base de datos original
list(data.columns.values)
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
# Medición del rendimiento
from timeit import timeit
t1 = timeit(lambda: list(data))
t2 = timeit(lambda: list(data.columns))
t3 = timeit(lambda: data.columns.tolist())
t4 = timeit(lambda: list(data.columns.values))
print (t1,t2,t3,t4)
# Out:
# 3.5329796400000077 1.709843052999986 0.5894188769999573 2.3846239040000228

# %%
data ['buying'].dtype
# Out:
# dtype('int64')

# %%
data ['persons'].dtype
# Out:
# dtype('int64')

# %%
data.dtypes
# Out:
# buying      int64
# maint       int64
# doors       int64
# persons     int64
# lug_boot    int64
# safety      int64
# class       int64
# dtype: object

# %%
#observando la cantidad de categorías de un atributo
data ["doors"].unique()
# Out:
# array([2, 3, 4, 5])

# %%
# cambiando tipo de datos
data ['doors'] = data ['doors'].astype('category')
data ['persons'] = data ['persons'].astype('category')

# %%
data.dtypes
# Out:
# buying         int64
# maint          int64
# doors       category
# persons     category
# lug_boot       int64
# safety         int64
# class          int64
# dtype: object

# %%
import numpy as np
#cambiando el nombre a las categorías con utilizando el método ‘where( )’
#indicando al atributo de la data, el nuevo nombre para cada categoría.
data["lug_boot"] = np.where(data["lug_boot"]=="small","pequeño",data["lug_boot"])
data["lug_boot"] = np.where(data["lug_boot"]=="med","mediano",data["lug_boot"])
data["lug_boot"] = np.where(data["lug_boot"]=="big","grande",data["lug_boot"])
data["lug_boot"].unique()
# Out:
# array(['0', '1', '2'], dtype=object)

# %%
#Contabilizando las frecuencias de cada categoría
data['doors'].value_counts(dropna=False)
# Out:
# doors
# 2    432
# 3    432
# 4    432
# 5    432
# Name: count, dtype: int64

# %%
#Juntando dos o más categorías mediante el método ‘where’ escribiendo la misma categoría para las que son diferentes.
data["doors"] = np.where(data["doors"]=="2","3 a menos",data["doors"])
data["doors"] = np.where(data["doors"]=="3","3 a menos",data["doors"])

data["doors"] = np.where(data["doors"]=="4","4 a más",data["doors"])
data["doors"] = np.where(data["doors"]=="5more","4 a más",data["doors"])

data["doors"].unique()
# Out:
# array(['2', '3 a menos', '4 a más', '5'], dtype=object)

# %%
# otro metodo
data.rename({'lug_boot': 'trunk'}, axis=1, inplace=True)
data
# Out:
#       buying  maint doors persons trunk  safety  class
# 0          3      3     2       2     0       0      0
# 1          3      3     2       2     0       1      0
# 2          3      3     2       2     0       2      0
# 3          3      3     2       2     1       0      0
# 4          3      3     2       2     1       1      0
# ...      ...    ...   ...     ...   ...     ...    ...
# 1723       0      0     5       5     1       1      2
# 1724       0      0     5       5     1       2      3
# 1725       0      0     5       5     2       0      0
# 1726       0      0     5       5     2       1      2
# 1727       0      0     5       5     2       2      3
#
# [1728 rows x 7 columns]

# %%
# Número de registros y atributos
data.shape
# Out:
# (1728, 7)

# %%
data.head()
# Out:
#    buying  maint doors persons trunk  safety  class
# 0       3      3     2       2     0       0      0
# 1       3      3     2       2     0       1      0
# 2       3      3     2       2     0       2      0
# 3       3      3     2       2     1       0      0
# 4       3      3     2       2     1       1      0

# %%
data.tail()
# Out:
#       buying  maint doors persons trunk  safety  class
# 1723       0      0     5       5     1       1      2
# 1724       0      0     5       5     1       2      3
# 1725       0      0     5       5     2       0      0
# 1726       0      0     5       5     2       1      2
# 1727       0      0     5       5     2       2      3

# %%
# Segmentación de filas y columnas
data.iloc[0:3,1:4]
# Out:
#    maint doors persons
# 0      3     2       2
# 1      3     2       2
# 2      3     2       2

# %%
data.loc[[0,10],:]
# Out:
#     buying  maint doors persons trunk  safety  class
# 0        3      3     2       2     0       0      0
# 10       3      3     2       4     0       1      0

# %%
data.loc[0:20,['doors','persons']]
# Out:
#    doors persons
# 0      2       2
# 1      2       2
# 2      2       2
# 3      2       2
# 4      2       2
# 5      2       2
# 6      2       2
# 7      2       2
# 8      2       2
# 9      2       4
# 10     2       4
# 11     2       4
# 12     2       4
# 13     2       4
# 14     2       4
# 15     2       4
# 16     2       4
# 17     2       4
# 18     2       5
# 19     2       5
# 20     2       5

# %%
#extrayendo los datos de una categoría en particular de un atributo.
data[data.buying == "vhigh"]
# Out:
# Empty DataFrame
# Columns: [buying, maint, doors, persons, trunk, safety, class]
# Index: []

# %%
data[(data.safety == "med") | (data.safety == "high")]
# Out:
# Empty DataFrame
# Columns: [buying, maint, doors, persons, trunk, safety, class]
# Index: []

# %%
#exportando nuestro documento a un csv
ruta = r'C:\Users\Usuario\Documents\5to CICLO\MINERÍA DE DATOS\SEMANA 3\archivo2.csv'
data.to_csv(ruta, index=False)
